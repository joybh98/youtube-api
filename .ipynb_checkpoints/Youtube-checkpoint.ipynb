# %%
from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON
from dateutil import parser
import seaborn as sns
import matplotlib.pyplot as plt

# %%
api_key='AIzaSyDPPDT9D8dZyuxceck_G6LBt73YTazhlIw'

# %%
channel_ids=['UCBJycsmduvYEL83R_U4JriQ',
            ]

# %%
api_service_name = "youtube"
api_version = "v3"

youtube=build(
    api_service_name,api_version,developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    
    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        
        all_data.append(data)
        
    return(pd.DataFrame(all_data))

# %%
channel_stats=get_channel_stats(youtube,channel_ids)

# %%
channel_stats
# Out:
#         channelName subscribers       views totalVideos  \
# 0  Marques Brownlee    15500000  2938510000        1428
#
#                  playlistId
# 0  UUBJycsmduvYEL83R_U4JriQ

# %%
playlist_id="PLBsP89CPrMeOYPjeabTfPW8UDC-WRn2Gi"

#function to get playlist_ids and store them in a list
def get_video_ids(youtube,playlist_id):
    # list to store video_ids
    video_ids=[]
    # get ids using youtube API
    request=youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults=50
    )
    response=request.execute()
    
    #add to video_ids
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
    
    #next_page_token as total number of videos are more than maxResults
    '''next_page_token=response.get('nextPageToken')
    #use a while loop; as long as next page token is not none i.e end of the playlist,
    # get video_ids
    while next_page_token is not None:
        request=youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=playlist_id,
            maxResults=50
        )
        response=request.execute()
        
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])
            
        next_page_token=response.get('nextPageToken')'''
    return video_ids

# %%
video_ids=get_video_ids(youtube,playlist_id)

# %%
len(video_ids)
# Out:
# 38

# %%
def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)

# %%
video_df=get_video_details(youtube,video_ids)
video_df
# Out:
#        video_id      channelTitle  \
# 0   ASwVyfebu3E  Marques Brownlee
# 1   NbzpwG4n6Vs  Marques Brownlee
# 2   iDKIw3OgNcg  Marques Brownlee
# 3   ZX5ajIAhKTk  Marques Brownlee
# 4   uwxxQ9FZXow  Marques Brownlee
# 5   sb77YWaEsi8  Marques Brownlee
# 6   wIaowvCQG1M  Marques Brownlee
# 7   nIs8xAr_nIo  Marques Brownlee
# 8   i7FtVfokRYU  Marques Brownlee
# 9   SGiOZnUQlEU  Marques Brownlee
# 10  MtUxFCicxuM  Marques Brownlee
# 11  Xyt9rmsxwDU  Marques Brownlee
# 12  DC-QGkKrxdM  Marques Brownlee
# 13  6joCzIxiUaE  Marques Brownlee
# 14  fL30bWrGrfE  Marques Brownlee
# 15  ELo58FBl3R8  Marques Brownlee
# 16  ilyTQSn2zRo  Marques Brownlee
# 17  xig77hiUHig  Marques Brownlee
# 18  sdw_jquVZe0  Marques Brownlee
# 19  ZNAxkJL5OKU  Marques Brownlee
# 20  2BQ1rCqG19Y  Marques Brownlee
# 21  VEVWRGC0OJA  Marques Brownlee
# 22  n_SDw2LQ9N8  Marques Brownlee
# 1    2163716     96839           None         4841  PT12M45S         hd
# 2    1545875     48993           None         2386  PT12M45S         hd
# 3     931252     47025           None         2828  PT11M56S         hd
# 4    1565578     51092           None         5043   PT10M8S         hd
# 5    1647843     55296           None         6426  PT10M34S         hd
# 6    2017267     57293           None         3249  PT13M12S         hd
# 7    1303143     45078           None         5581  PT11M26S         hd
# 8     839482     32775           None         3270  PT10M44S         hd
# 9    1503102     48511           None         2343  PT15M50S         hd
# 10   1357444     48137           None         3123   PT9M40S         hd
# 11    843881     48063           None         3430  PT11M19S         hd
# 12    882240     40582           None         2135      PT9M         hd
# 13   1043394     47663           None         2740  PT12M48S         hd
# 14   1933100     98350           None         7667  PT10M41S         hd
# 15   1073725     43532           None         2521   PT9M30S         hd
# 16   1172362     44463           None         2350    PT9M6S         hd
# 17   1812155     44985           None         2912   PT9M16S         hd
# 18   1001129     44509           None         2648  PT10M33S         hd
# 19   1702403     47274           None         6541   PT8M34S         hd
# 20    994579     40893           None         3560   PT9M42S         hd
# 21   1215320     42575           None         2857   PT7M45S         hd
# 22   1074827     39382           None         3271    PT7M2S         hd
# 23    983103     37738           None         1760   PT7M43S         hd
# 24    730130     33688           None         1582   PT5M52S         hd
# 25   1061331     47690           None         3810   PT6M10S         hd
# 26   1333831     63921           None         3153   PT10M2S         hd
# 27    845947     34053           None         4125    PT8M8S         hd
# 28    831783     36923           None         2399   PT8M21S         hd
# 29    950678     33254           None         4123   PT7M13S         hd
# 30    694465     27387           None         1629   PT5M16S         hd
# 31    945627     28325           None         3044   PT8M55S         hd
# 32    705134     26578           None         1729   PT7M53S         hd
# 33    637688     21537           None         1713   PT7M51S         hd
# 34    397631     28395           None         3539   PT8M58S         hd
# 35    318855     15121           None         1558   PT5M59S         hd
# 36    458012     16634           None         2180   PT6M52S         hd
# 37   1237964     44459           None         5487   PT8M14S         hd
#
#    caption
# 0    false
# 1    false
# 2    false
# 3    false
# 4    false
# 5    false
# 6    false
# 7    false
# 8    false
# 9    false
# 10   false
# 11   false
# 12   false
# 13   false
# 14   false
# 15   false
# 16   false
# 17   false
# 18   false
# 19   false
# 20   false
# 21   false
# 22   false
# 23   false
# 24   false
# 25   false
# 26   false
# 27   false
# 28   false
# 29   false
# 30   false
# 31   false
# 32   false
# 33   false
# 34   false
# 35   false
# 36   false
# 37   false

# %%
def get_comments_in_videos(youtube, video_ids):
    
    all_comments = []
    
    for video_id in video_ids:
        try:   
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id
            )
            response = request.execute()
        
            comments_in_video = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items'][0:10]]
            comments_in_video_info = {'video_id': video_id, 'comments': comments_in_video}

            all_comments.append(comments_in_video_info)
            
        except: 
            # When error occurs - most likely because comments are disabled on a video
            print('Could not get comments for video ' + video_id)
        
    return pd.DataFrame(all_comments)

# %%
comments_df=get_comments_in_videos(youtube,video_ids)
comments_df
# Out:
#        video_id                                           comments
isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags              False
# publishedAt       False
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount      False
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
numeric_cols=['viewCount','likeCount','favouriteCount','commentCount']
video_df[numeric_cols]=video_df[numeric_cols].apply(pd.to_numeric,errors='coerce',axis=1)

# %%
video_df.dtypes
# Out:
# video_id           object
# channelTitle       object
# title              object
# description        object
# tags               object
# publishedAt        object
# viewCount         float64
# likeCount         float64
# favouriteCount    float64
# commentCount      float64
# duration           object
# definition         object
# caption            object
# dtype: object

# %%
# get published day in the week from publishedAt
video_df['publishedAt']=video_df['publishedAt'].apply(lambda x:parser.parse(x))
video_df['publishedDayName']=video_df['publishedAt'].apply(lambda x:x.strftime("%A"))

# %%
import isodate
video_df['durationSecs']=video_df['duration'].apply(lambda x:isodate.parse_duration(x))
video_df['durationSecs']=video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df[['durationSecs','duration']]
# Out:
#     durationSecs  duration
# 0          807.0  PT13M27S
# 1          765.0  PT12M45S
# 2          765.0  PT12M45S
# 3          716.0  PT11M56S
# 4          608.0   PT10M8S
# 5          634.0  PT10M34S
# 6          792.0  PT13M12S
# 7          686.0  PT11M26S
# 8          644.0  PT10M44S
# 9          950.0  PT15M50S
# 10         580.0   PT9M40S
# 11         679.0  PT11M19S
# 12         540.0      PT9M
# 13         768.0  PT12M48S
# 14         641.0  PT10M41S
# 15         570.0   PT9M30S
# 16         546.0    PT9M6S
# 17         556.0   PT9M16S
# 18         633.0  PT10M33S
# 19         514.0   PT8M34S
# 20         582.0   PT9M42S
# 21         465.0   PT7M45S
# 22         422.0    PT7M2S
# 23         463.0   PT7M43S
# 24         352.0   PT5M52S
# 25         370.0   PT6M10S
# 26         602.0   PT10M2S
# 27         488.0    PT8M8S
# 28         501.0   PT8M21S
# 29         433.0   PT7M13S
# 30         316.0   PT5M16S
# 31         535.0   PT8M55S
# 32         473.0   PT7M53S
# 33         471.0   PT7M51S
# 34         538.0   PT8M58S
# 35         359.0   PT5M59S
# 36         412.0   PT6M52S
# 37         494.0   PT8M14S

# %%
# add tag count
video_df['tagCount']=video_df['tags'].apply(lambda x:len(x))

# %%
video_df
# Out:
#        video_id      channelTitle  \
# 0   ASwVyfebu3E  Marques Brownlee
# 1   NbzpwG4n6Vs  Marques Brownlee
# 2   iDKIw3OgNcg  Marques Brownlee
# 3   ZX5ajIAhKTk  Marques Brownlee
# 4   uwxxQ9FZXow  Marques Brownlee
# 5   sb77YWaEsi8  Marques Brownlee
# 6   wIaowvCQG1M  Marques Brownlee
# 7   nIs8xAr_nIo  Marques Brownlee
# 8   i7FtVfokRYU  Marques Brownlee
# 9   SGiOZnUQlEU  Marques Brownlee
# 10  MtUxFCicxuM  Marques Brownlee
# 11  Xyt9rmsxwDU  Marques Brownlee
# 12  DC-QGkKrxdM  Marques Brownlee
# 30                            Ask MKBHD V7: CES 2016!
# 31                 Ask MKBHD V6! 4K on a Smartphone?!
# 32                                Ask MKBHD V5! #HYPE
# 33                                      Ask MKBHD V4!
# 34                                      Ask MKBHD V3!
# 35                                      Ask MKBHD V2!
# 36                                      Ask MKBHD V1!
# 37                               Five Facts About Me!
#
#                                           description  \
# 0   Are rollable displays a good idea?  What's com...
# 1   This video is 8K because why the hell not.\nOn...
# 2   Folding phone debate? OnePlus 7 rumors? Invent...
# 3   I literally can't believe how much noise gets ...
# 4   We've got a lot to talk about in this busy #te...
# 5   2018 iPhone Xr: Only 3GB of RAM and a 720p dis...
# 6   August has been nuts. We gotta lot to talk abo...
# 7   Unboxing an iBook with iJustine: https://youtu...
# 8   Special Edition 6 colors: https://goo.gl/hdtQf...
# 9   Peter McKinnon: http://youtube.com/petermckinn...
# 10  Tech questions. Tech answers. Leggo.\n\nNew Yo...
# 11  1K in 4K. JK not all 4K. Still cool tho.\n\nTh...
# 12  The Shorty Award? My Tech Backpack? Your Quest...
# 13  Answering Twitter questions with some special ...
# 14  The ultimate Apple conspiracy theory, confirme...
# 15  Follow on Twitter. Hint hint. http://twitter.c...
# 16  RIP Headphone Jack.\n\nCasey's video: https://...
# 17  iPhone comparisons? FaceID vs TouchID? FAQs of...
# 18  MKBHD Circuit Shirt: https://teespring.com/MKB...
# 19  Unboxings. Rants. Questions. Answers.\n\nMX Ma...
# 20  Should I vlog? Is OnePlus cheating? The best o...
# 21  The best of your questions from May! Plus bonu...
# 22  iPhone 8? Pixel 2? Daily vlogs?  Note 8? Lots ...
# 23  Talking tech, YouTube and sponsors.\n\nTesla P...
# 24  YouTuber of the Year voting: http://shortyawar...
# 25  Answering your Pre-CES questions to start 2017...
# 26  Questions and Answers from the completed studi...
# 27  Questions and Answers from the nearly complete...
# 28  Questions and Answers about the studio build!\...
# 29  Q&A about a new studio, Tesla Model 3 etc!\n\n...
# 30  Questions and Answers from Las Vegas!\n\nWhat'...
# 31  Video AMA #6 - Questions from Twitter. Just DO...
# 32  Video AMA #5 - Questions from Twitter! The hyp...
# 33  Graduation = May 20th!\n\nMKBHD Shirt V1: http...
# 34  Third Q&A video, featuring your questions!\n\n...
# 35  Second Q&A in a new series!\n\nNY Rumble Ultim...
# 36  First Q&A video in a new series!\n\ndBrand Nex...
# 37  5 Facts about me! Awesome links are below.\n\n...
#
#                                                  tags  \
# 0   [rollable phone, rollable display, MKBHD, EOS ...
# 1   [askMKBHD, MKBHD, 8K, HDR, Tesla, Tesla Model ...
# 2   [Galaxy Fold vs Mate X, Huawei Mate X, Galaxy ...
# 3   [AskMKBHD, #AskMKBHD, Ask, MKBHD, Tesla Roadst...
# 4   [Pixel 3, Pixel 3 XL, Pixel 3 display, scratch...
# 5   [iPhone Xr, iPhone xr, iPhone XR, iPhone Xr di...
# 6   [Ask MKBHD, PocoF1, Poco F1, Pocophone, Xiaomi...
# 7   [Ask MKBHD, iJustine, Justine, New Macbook Pro...
# 8   [Hot Ones, MKBHD, Hot Ones MKBHD, Ask MKBHD, A...
# 9   [Peter McKinnon, McKinnon, mckinnon, mkbhd, AS...
# 10  [Pixel 3, notch, Piexl 3 notch, rumors, Pixel ...
# 11                    [Ask MKBHD, MKBHD, 1000 videos]
# 12  [MKBHD, shorty award, shorty awards, youtuber,...
# 13  [MKBHD, Ask MKBHD, Tesla Model 3, Austin Evans...
# 14  [Apple Slowing down iPhones, Apple throttling ...
# 15  [Ask MKBHD, AskMKBHD, #AskMKBHD, Thanksgiving,...
# 16  [Ask MKBHD, AskMKBHD, #AskMKBHD, MKBHD, Demone...
# 17  [iPhone X vs iPhone 8, iPhone X vs, iPhone 8 v...
# 18  [Ask MKBHD, snakes, studio, shirt, MKBHD Shirt...
# 19  [Ask MKBHD, Q&A, Ask, MKBHD, Ask Me, Note 7, G...
# 20  [Ask MKBHD, MKBHD vlog, OnePlus 5, OnePlus, up...
# 21  [AskMKBHD, Ask MKBHD, Q&A, Questions, Answers,...
# 22  [Ask MKBHD, AskMKBHD, Q&A, questions and answe...
# 23  [AskMKBHD, Ask MKBHD, Q&A, Questions and answe...
# 24  [youtuber of the year, shorty award, vulfpeck,...
# 25  [Ask MKBHD, Q&A, Questions and Answers, Q & A,...
# 26  [Ask MKBHD, Ask, MKBHD, Q&A, questions and ans...
# 27          [mkbhd, ASK MKBHD, askmkbhd, v10, studio]
# 28  [Ask MKBHD, AskMKBHD, MKBHD, Q&A, Q and A, Stu...
# 29  [Ask MKBHD, AskMKBHD, MKBHD, Ask Me, Q&A, AMA,...
# 30  [Ask MKBHD, Ask Me, MKBHD, CES 2016, #CES2016,...
# 31  [Marques Brownlee (Person), mkbhd, ask mkbhd, ...
# 32                        [Ask MKBHD, Ask, MKVHD, V5]
# 33  [Ask MKBHD, AskMKBHD, Ask me, V4, Ask MKBHD V4...
# 34  [Ask MKBHD, MKBHD, Ask Me, AskMe, #AskMKBHD, #...
# 35  [MKBHD, Ask Me, Ask MKBHD, OnePlus One, OnePlu...
# 36  [MKBHD, Ask Me, Ask MKBHD, Galaxy S5, HTC One,...
# 37  [Five, Facts, About, Me, MKBHD, Marques Brownl...
#
#                  publishedAt  viewCount  likeCount  favouriteCount  \
# 0  2020-03-17 00:04:05+00:00  2807140.0    96461.0             NaN
# 1  2020-01-06 00:30:45+00:00  2163716.0    96839.0             NaN
# 2  2019-05-01 00:14:24+00:00  1545875.0    48993.0             NaN
# 3  2019-01-07 21:52:33+00:00   931252.0    47025.0             NaN
# 4  2018-10-25 00:35:06+00:00  1565578.0    51092.0             NaN
# 5  2018-09-26 23:30:44+00:00  1647843.0    55296.0             NaN
# 6  2018-08-24 21:16:15+00:00  2017267.0    57293.0             NaN
# 7  2018-07-16 20:25:58+00:00  1303143.0    45078.0             NaN
# 8  2018-06-25 21:40:15+00:00   839482.0    32775.0             NaN
# 15        2521.0   PT9M30S         hd   false         Thursday         570.0
# 16        2350.0    PT9M6S         hd   false        Wednesday         546.0
# 17        2912.0   PT9M16S         hd   false          Tuesday         556.0
# 18        2648.0  PT10M33S         hd   false         Thursday         633.0
# 19        6541.0   PT8M34S         hd   false          Tuesday         514.0
# 20        3560.0   PT9M42S         hd   false           Friday         582.0
# 21        2857.0   PT7M45S         hd   false           Monday         465.0
# 22        3271.0    PT7M2S         hd   false         Thursday         422.0
# 23        1760.0   PT7M43S         hd   false           Monday         463.0
# 24        1582.0   PT5M52S         hd   false         Saturday         352.0
# 25        3810.0   PT6M10S         hd   false          Tuesday         370.0
# 26        3153.0   PT10M2S         hd   false           Friday         602.0
# 27        4125.0    PT8M8S         hd   false          Tuesday         488.0
# 28        2399.0   PT8M21S         hd   false           Friday         501.0
# 29        4123.0   PT7M13S         hd   false           Sunday         433.0
# 30        1629.0   PT5M16S         hd   false          Tuesday         316.0
# 31        3044.0   PT8M55S         hd   false           Monday         535.0
# 32        1729.0   PT7M53S         hd   false           Friday         473.0
# 33        1713.0   PT7M51S         hd   false         Thursday         471.0
# 34        3539.0   PT8M58S         hd   false         Thursday         538.0
# 35        1558.0   PT5M59S         hd   false         Thursday         359.0
# 36        2180.0   PT6M52S         hd   false           Sunday         412.0
# 37        5487.0   PT8M14S         hd   false           Friday         494.0
#
#     tagCount
# 0         12
# 1          9
# 2          5
# 3         11
# 4         17
# 5         12
# 6         10
# 7          9
# 8         22
# 9         13
# 10         9
# 11         3
# 12         7
# 13         7
# 14        13
# 15        10
# 16        12
# 17        10
# 18         9
# 19        16
# 20        10
# 21        15
# 22         7
# 23         9
# 24         7
# 25         9
# 26        20
# 27         5
# 28        11
# 29         7
# 30         7
# 31         8
# 32         4
# 33        10
# 34         6
# 35        13
# 36        13
# 37        11

# %% [markdown]
# # EDA

# %% [markdown]
# ## Best Performing Videos

# %%
ax=sns.barplot(x='title',y='viewCount',data=video_df.sort_values('viewCount',ascending=False)[0:9])
plot=ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x,pos:'{:,.0f}'.format(x/1000+'K')))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_122/2929933823.py in <module>
#       1 ax=sns.barplot(x='title',y='viewCount',data=video_df.sort_values('viewCount',ascending=False)[0:9])
#       2 plot=ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# ----> 3 ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x,pos:'{:,.0f}'.format(x/1000+'K')))
#
# NameError: name 'ticker' is not defined

# %% [markdown]
# ## Worst Performing Videos

# %%
ax=sns.barplot(x='title',y='viewCount',data=video_df.sort_values('viewCount',ascending=True)[0:9])
plot=ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x,pos:'{:,.0f}'.format(x/1000+'K')))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_122/4042184505.py in <module>
#       1 ax=sns.barplot(x='title',y='viewCount',data=video_df.sort_values('viewCount',ascending=True)[0:9])
#       2 plot=ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# ----> 3 ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x,pos:'{:,.0f}'.format(x/1000+'K')))
#
# NameError: name 'ticker' is not defined

# %% [markdown]
# ## View Distribution Per Video

# %%
sns.violinplot(video_df['channelTitle'],video_df['viewCount'])
# Out:
# /home/joy/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='channelTitle', ylabel='viewCount'>
